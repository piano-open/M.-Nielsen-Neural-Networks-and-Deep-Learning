# %% [markdown]
# <h1>M. Nielsen, Chapter 6, 5th cnn model (expand data set with rotation, 2)</h1>

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import os
import numpy as np
import time
import random
from winsound import Beep
from PIL import Image
import pickle
import tensorflow as tf # changed to intel-optimized build
Beep(1000, 100)
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from matplotlib import pyplot as plt

# %%
os.chdir(r"C:\Users\mchen\OneDrive\桌面\ml\code\tutorial\chapter6\env")

# %% [markdown]
# <h1>expand training data</h1>

# %%
# ###############################################
# #    load data from local directory
# ###############################################

# import mnist_loader
# training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
# del training_data

# %%
# ###############################################
# #    expand training data
# ###############################################
# expanded_training_pairs = []
# j = 0 # counter
# for data in training_data:
#     x = data[0]
#     y = data[1]
#     expanded_training_pairs.append((x, y))
#     image = x.reshape((28, 28))
#     j += 1
#     if j % 10000 == 0: print("Expanding image number", j)
#     # iterate over data telling us the details of how to
#     # do the displacement
#     for d, axis, index_position, index in [
#             (1,  0, "first", 0),
#             (-1, 0, "first", 27),
#             (1,  1, "last",  0),
#             (-1, 1, "last",  27)]:
#         new_img = np.roll(image, d, axis)
#         if index_position == "first": 
#             new_img[index, :] = np.zeros(28)
#         else: 
#             new_img[:, index] = np.zeros(28)
#         expanded_training_pairs.append((np.reshape(new_img, 784), y))
# # random.shuffle(expanded_training_pairs)
# expanded_training_data = [list(d) for d in expanded_training_pairs]

# Beep(1000, 100)
# del expanded_training_pairs
# del training_data

# os.chdir(r"C:\Users\mchen\OneDrive\桌面\ml\code\tutorial\chapter6\env")
# with open('expanded_training_data.pkl', 'wb') as f:
#     pickle.dump(expanded_training_data, f)

# %%
# os.chdir(r"C:\Users\mchen\OneDrive\桌面\ml\code\tutorial\chapter6\env")
# with open('expanded_training_data.pkl', 'rb') as f:
#     expanded_training_data = pickle.load(f)

# %%
# def gen_image_rot(arr):
#     two_d = (np.reshape(arr, (28, 28)) * 255).astype(np.uint8)
#     img = Image.fromarray(two_d, 'L')
#     img1 = img.rotate(2.5)
#     img2 = img.rotate(-2.5)
#     A = np.reshape(np.array(img1)/255, (28*28, 1)).astype(np.float32)
#     B = np.reshape(np.array(img2)/255, (28*28, 1)).astype(np.float32)
#     return A, B

# super_expanded_training_pairs = []
# j = 0 # counter
# for data in expanded_training_data:
#     x = data[0]
#     y = data[1]
#     j += 1
#     if j % 10000 == 0: print("Expanding image number", j)
#     super_expanded_training_pairs.append((x, y))
#     a, b = gen_image_rot(x)
#     super_expanded_training_pairs.append((np.reshape(a, 784), y))
#     super_expanded_training_pairs.append((np.reshape(b, 784), y))

    
# super_expanded_training_data = [list(d) for d in super_expanded_training_pairs]
# Beep(1000, 100)

# del expanded_training_data
# del super_expanded_training_pairs

# os.chdir(r"C:\Users\mchen\OneDrive\桌面\ml\code\tutorial\chapter6\env")
# with open('super_expanded_training_data.pkl', 'wb') as f:
#     pickle.dump(super_expanded_training_data, f)

# %%
# os.chdir(r"C:\Users\mchen\OneDrive\桌面\ml\code\tutorial\chapter6\env")
# with open('super_expanded_training_data.pkl', 'rb') as f:
#     super_expanded_training_data = pickle.load(f)
    
# Beep(1000, 100)

# %%
# leg1 = super_expanded_training_data[:100000]
# super_expanded_training_data = super_expanded_training_data[100000:]
# leg2 = super_expanded_training_data[:100000]
# super_expanded_training_data = super_expanded_training_data[100000:]
# leg3 = super_expanded_training_data[:100000]
# super_expanded_training_data = super_expanded_training_data[100000:]
# leg4 = super_expanded_training_data[:100000]
# super_expanded_training_data = super_expanded_training_data[100000:]
# leg5 = super_expanded_training_data[:100000]
# super_expanded_training_data = super_expanded_training_data[100000:]
# leg6 = super_expanded_training_data[:100000]
# super_expanded_training_data = super_expanded_training_data[100000:]
# leg7 = super_expanded_training_data[:100000]
# super_expanded_training_data = super_expanded_training_data[100000:]
# leg8 = super_expanded_training_data

# %%
# ###############################################
# #    convert data format
# ###############################################

# train_x, train_y, val_x, val_y, test_x, test_y = [], [], [], [], [], []


# j = 0 # counter
# for leg in [leg1, leg2, leg3, leg4, leg5, leg6, leg7, leg8]:
#     for tra in leg:
#         img_tra_x = tra[0].reshape(28,28).tolist()
#         img_tra_y = np.array(np.argmax(tra[1]), dtype=np.uint8)
#         train_x.append(img_tra_x)
#         train_y.append(img_tra_y)
#         j += 1
#         if j % 10000 == 0: print("processed image number", j)
#     del leg
# del j



# for val in validation_data:
#     img_val_x = val[0].reshape(28,28)
# #     img_val_y = np.array(np.argmax(val[1]), dtype=np.uint8)
#     img_val_y = np.array(val[1], dtype=np.uint8)
#     val_x.append(img_val_x)
#     val_y.append(img_val_y)
# print(np.shape(val_x))
# del validation_data


# for tes in test_data:
#     img_tes_x = tes[0].reshape(28,28)
#     img_tes_y = np.array(tes[1], dtype=np.uint8)
#     test_x.append(img_tes_x)
#     test_y.append(img_tes_y)
# print(np.shape(test_x))
# del test_data


# train_x = np.array(train_x)
# val_x = np.array(val_x)
# test_x = np.array(test_x)

# train_y = np.array(train_y)
# val_y = np.array(val_y)
# test_y = np.array(test_y)

# Beep(1000, 100)
# print('ok')

# %%
# useful_e_data = [train_x, val_x, test_x, train_y, val_y, test_y]

# pickle.dump(useful_e_data, open("useful_e_data.pkl", 'wb'), protocol=4)

# Beep(1000, 100)

# %% [markdown]
# <h1>load expanded training data</h1>

# %%
os.chdir(r"C:\Users\mchen\OneDrive\桌面\ml\code\tutorial\chapter6\env")
with open('useful_e_data.pkl', 'rb') as f:
    [train_x, val_x, test_x, train_y, val_y, test_y] = pickle.load(f)
    
Beep(1000, 100)

# %%
# ###############################################
# #    checking expanded data
# ###############################################

# for i in range(5):
#     plt.imshow(train_x[i], interpolation='none')
#     plt.show()
#     print('img label:', train_y[i])

# %% [markdown]
# <h1>Relu CNN model as described in M. Nielsen, Chapter 6</h1>
# <h1>(Using my own hyper params)</h1>

# %%
# >>> from network3 import ReLU
# >>> net = Network([
#         ConvPoolLayer(image_shape=(mini_batch_size, 1, 28, 28), 
#                       filter_shape=(20, 1, 5, 5), 
#                       poolsize=(2, 2), 
#                       activation_fn=ReLU),
#         ConvPoolLayer(image_shape=(mini_batch_size, 20, 12, 12), 
#                       filter_shape=(40, 20, 5, 5), 
#                       poolsize=(2, 2), 
#                       activation_fn=ReLU),
#         FullyConnectedLayer(n_in=40*4*4, n_out=100, activation_fn=ReLU),
#         SoftmaxLayer(n_in=100, n_out=10)], mini_batch_size)
# >>> net.SGD(training_data, 60, mini_batch_size, 0.03, 
#             validation_data, test_data, lmbda=0.1)

# %% [markdown]
# <h1>Reshape data</h1>

# %%
# reshape data
train_x = train_x.reshape(np.shape(train_x)[0], np.shape(train_x)[1], np.shape(train_x)[2], 1)
val_x = val_x.reshape(np.shape(val_x)[0], np.shape(val_x)[1], np.shape(val_x)[2], 1)
test_x = test_x.reshape(np.shape(test_x)[0], np.shape(test_x)[1], np.shape(test_x)[2], 1)

train_y = tf.one_hot(train_y.astype(np.int32), depth=10)
val_y = tf.one_hot(val_y.astype(np.int32), depth=10)
test_y = tf.one_hot(test_y.astype(np.int32), depth=10)
Beep(1000, 100)

# %% [markdown]
# <h1>Build Network model (relu, better h-param)</h1>

# %%
# ################################################################
# #   relu CNN network as described in chapter 6
# ################################################################
# tf.random.set_seed(42)
# # tf.random.set_seed(24)
# ################################################################


# #################################
# #    h-param base line
# #################################
# lmbda = 0.1 / 10 / 10 / 10
# eta = 0.03
# n_eph = 20

# batch_size = 10
# n_eph = 23




# ################################################################
# print('lmbda= {}\n'.format(lmbda))
# print('eta= {}\n'.format(eta))
# print('n_eph= {}\n'.format(n_eph))
# print('batch_size= {}\n'.format(batch_size))
# print('n_eph= {}\n'.format(n_eph))
# ################################################################


# ################################################################
# # construct netwoek model
# input_shape = (28, 28, 1)
# model = tf.keras.models.Sequential()
# model.add(tf.keras.layers.Conv2D( # no padding
#         20,
#         (5,5),
#         activation=tf.nn.relu,
#         kernel_regularizer=tf.keras.regularizers.L2(l2=lmbda),
#         input_shape=input_shape))

# model.add(tf.keras.layers.MaxPool2D(strides=(2,2)))

# model.add(tf.keras.layers.Conv2D( # no padding
#         40,
#         (5,5),
#         activation=tf.nn.relu,
#         kernel_regularizer=tf.keras.regularizers.L2(l2=lmbda)))

# model.add(tf.keras.layers.MaxPool2D(strides=(2,2)))

# model.add(tf.keras.layers.Flatten())

# model.add(tf.keras.layers.Dense(
#         100,
#         activation=tf.nn.relu,
#         kernel_regularizer=tf.keras.regularizers.L2(l2=lmbda)))

# model.add(tf.keras.layers.Dense(10,activation=tf.nn.softmax))
# ################################################################

# ################################################################
# # compile model
# model.compile(
#     optimizer=tf.keras.optimizers.SGD(
#         learning_rate=eta,
#         momentum=0.0,
#         nesterov=False,
#         name="SGD"),
#     loss='categorical_crossentropy',
#     metrics=['accuracy']
# )

# ################################################################

# model.summary()

# ################################################################
# # save the model when val_acc is best
# checkpoint_filepath = r'C:\Users\mchen\OneDrive\桌面\ml\code\tutorial\chapter6\save_model\expansion\expansion'

# model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
#     filepath=checkpoint_filepath,
#     save_weights_only=True,
#     monitor='val_accuracy',
#     mode='max',
#     save_best_only=True)
# ################################################################

# ################################################################
# #    train model  (how do i randomize mini_batches?)


# ts = time.time()
# history = model.fit(
#     train_x, train_y, 
#     epochs=n_eph,
#     batch_size=batch_size,
#     validation_data=(val_x, val_y),
#     callbacks=[model_checkpoint_callback],
#     shuffle=True
# )
# te = time.time()

# print('total time:', te - ts)


# acc = history.history['accuracy']
# loss = history.history['loss']
# val_acc = history.history['val_accuracy']
# val_loss = history.history['val_loss']
# ################################################################


# ################################################################
# #    load the weights for the best epoch (best val accuracy)
# model.load_weights(checkpoint_filepath)

# ################################################################

# ################################################################
# #    evaluate test data at the best epoch
# [test_data_loss, test_data_accuracy] = model.evaluate(
#     test_x, test_y,
#     batch_size=len(test_x)
# )
# ################################################################


# plt.plot(acc, label='train acc., best: {:.3f}'.format(max(acc)))
# plt.plot(val_acc, label='validation acc. best: {:.3f}'.format(max(val_acc)))
# plt.title('CNN relu, expanded train data, SGD, , eta={}, lmbda={}, {} epochs'.format(eta, lmbda, n_eph))
# plt.axvline(x=np.argmax(val_acc), c='r', ls=':', label='best epoch: {}'.format(np.argmax(val_acc)))
# plt.axhline(y=test_data_accuracy, c='r', label='test data accuracy at best epoch: {:.3f}'.format(test_data_accuracy))
# plt.legend()
# plt.show()

# Beep(1000, 100)


# print('acc', acc)
# print('loss', loss)
# print('val_acc', val_acc)
# print('val_loss', val_loss)
# Out:
# lmbda= 0.0001
#
# eta= 0.03
#
# n_eph= 23
#
# batch_size= 10
#
# n_eph= 23
#
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 24, 24, 20)        520
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 12, 12, 20)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 8, 8, 40)          20040
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 4, 40)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 640)               0
# _________________________________________________________________
# dense (Dense)                (None, 100)               64100
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 85,670
# Trainable params: 85,670
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/23
# 25000/25000 [==============================] - 107s 4ms/step - loss: 0.1051 - accuracy: 0.9744 - val_loss: 0.0635 - val_accuracy: 0.9886
# Epoch 2/23
# 25000/25000 [==============================] - 157s 6ms/step - loss: 0.0497 - accuracy: 0.9917 - val_loss: 0.0509 - val_accuracy: 0.9926
# Epoch 3/23
# 25000/25000 [==============================] - 119s 5ms/step - loss: 0.0401 - accuracy: 0.9945 - val_loss: 0.0464 - val_accuracy: 0.9930
# Epoch 4/23
# 25000/25000 [==============================] - 112s 4ms/step - loss: 0.0347 - accuracy: 0.9956 - val_loss: 0.0514 - val_accuracy: 0.9914
# Epoch 5/23
# 25000/25000 [==============================] - 118s 5ms/step - loss: 0.0305 - accuracy: 0.9963 - val_loss: 0.0545 - val_accuracy: 0.9896 - ETA: 0s - loss: 0.0304 - accuracy - ETA: 0s - loss: 0.0305 - accura
# Epoch 6/23
# 25000/25000 [==============================] - 115s 5ms/step - loss: 0.0275 - accuracy: 0.9970 - val_loss: 0.0472 - val_accuracy: 0.9928
# Epoch 7/23
# 25000/25000 [==============================] - 120s 5ms/step - loss: 0.0260 - accuracy: 0.9972 - val_loss: 0.0461 - val_accuracy: 0.9924
# Epoch 8/23
# 25000/25000 [==============================] - 124s 5ms/step - loss: 0.0239 - accuracy: 0.9976 - val_loss: 0.0416 - val_accuracy: 0.9941
# Epoch 9/23
# 25000/25000 [==============================] - 120s 5ms/step - loss: 0.0230 - accuracy: 0.9976 - val_loss: 0.0412 - val_accuracy: 0.9934
# Epoch 10/23
# 25000/25000 [==============================] - 122s 5ms/step - loss: 0.0221 - accuracy: 0.9978 - val_loss: 0.0392 - val_accuracy: 0.9941
# Epoch 11/23
# 25000/25000 [==============================] - 140s 6ms/step - loss: 0.0210 - accuracy: 0.9980 - val_loss: 0.0452 - val_accuracy: 0.9927
# val_acc [0.9886000156402588, 0.9926000237464905, 0.9929999709129333, 0.9914000034332275, 0.9896000027656555, 0.9927999973297119, 0.9923999905586243, 0.9940999746322632, 0.993399977684021, 0.9940999746322632, 0.9926999807357788, 0.991599977016449, 0.9936000108718872, 0.9926999807357788, 0.9950000047683716, 0.9933000206947327, 0.9927999973297119, 0.9926000237464905, 0.9937999844551086, 0.9933000206947327, 0.9905999898910522, 0.9923999905586243, 0.9925000071525574]
# val_loss [0.06347892433404922, 0.05087655782699585, 0.0463511124253273, 0.05140605568885803, 0.054536622017621994, 0.04720790684223175, 0.04605728015303612, 0.04157378524541855, 0.04119320213794708, 0.039152707904577255, 0.0452137254178524, 0.044234201312065125, 0.03989052399992943, 0.042020536959171295, 0.0347188338637352, 0.04157118499279022, 0.0430094413459301, 0.04094706103205681, 0.03699281066656113, 0.04040003940463066, 0.04968486353754997, 0.043319087475538254, 0.044874876737594604]

# %% [markdown]
# <h1>Expanding training data results in 99.4% test accuracy.<h1/>

# %% [markdown]
# <h1>rotate, no scheduling<h1/>

# %%
# ################################################################
# #   relu CNN network as described in chapter 6
# ################################################################
# tf.random.set_seed(42)
# # tf.random.set_seed(24)
# ################################################################


# #################################
# #    h-param base line
# #################################
# lmbda = 0.1 / 10 / 10 / 10
# eta = 0.03

# batch_size = 10
# n_eph = 88




# ################################################################
# print('lmbda= {}\n'.format(lmbda))
# print('eta= {}\n'.format(eta))
# print('n_eph= {}\n'.format(n_eph))
# print('batch_size= {}\n'.format(batch_size))
# print('n_eph= {}\n'.format(n_eph))
# ################################################################


# ################################################################
# # construct netwoek model
# input_shape = (28, 28, 1)
# model = tf.keras.models.Sequential()
# model.add(tf.keras.layers.Conv2D( # no padding
#         20,
#         (5,5),
#         activation=tf.nn.relu,
#         kernel_regularizer=tf.keras.regularizers.L2(l2=lmbda),
#         input_shape=input_shape))

# model.add(tf.keras.layers.MaxPool2D(strides=(2,2)))

# model.add(tf.keras.layers.Conv2D( # no padding
#         40,
#         (5,5),
#         activation=tf.nn.relu,
#         kernel_regularizer=tf.keras.regularizers.L2(l2=lmbda)))

# model.add(tf.keras.layers.MaxPool2D(strides=(2,2)))

# model.add(tf.keras.layers.Flatten())

# model.add(tf.keras.layers.Dense(
#         100,
#         activation=tf.nn.relu,
#         kernel_regularizer=tf.keras.regularizers.L2(l2=lmbda)))

# model.add(tf.keras.layers.Dense(10,activation=tf.nn.softmax))
# ################################################################

# ################################################################
# # compile model
# model.compile(
#     optimizer=tf.keras.optimizers.SGD(
#         learning_rate=eta,
#         momentum=0.0,
#         nesterov=False,
#         name="SGD"),
#     loss='categorical_crossentropy',
#     metrics=['accuracy']
# )

# ################################################################

# model.summary()

# ################################################################
# # save the model when val_acc is best
# checkpoint_filepath = r'C:\Users\mchen\OneDrive\桌面\ml\code\tutorial\chapter6\save_model\expansion\expansion'

# model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
#     filepath=checkpoint_filepath,
#     save_weights_only=True,
#     monitor='val_accuracy',
#     mode='max',
#     save_best_only=True)
# ################################################################

# ################################################################
# #    train model  (how do i randomize mini_batches?)


# ts = time.time()
# history = model.fit(
#     train_x, train_y, 
#     epochs=n_eph,
#     batch_size=batch_size,
#     validation_data=(val_x, val_y),
#     callbacks=[model_checkpoint_callback],
#     shuffle=True
# )
# te = time.time()

# print('total time:', te - ts)


# acc = history.history['accuracy']
# loss = history.history['loss']
# val_acc = history.history['val_accuracy']
# val_loss = history.history['val_loss']
# ################################################################


# ################################################################
# #    load the weights for the best epoch (best val accuracy)
# model.load_weights(checkpoint_filepath)

# ################################################################

# ################################################################
# #    evaluate test data at the best epoch
# [test_data_loss, test_data_accuracy] = model.evaluate(
#     test_x, test_y,
#     batch_size=len(test_x)
# )
# ################################################################


# plt.plot(acc, label='train acc., best: {:.3f}'.format(max(acc)))
# plt.plot(val_acc, label='validation acc. best: {:.3f}'.format(max(val_acc)))
# plt.title('CNN relu, expanded train data, SGD, , eta={}, lmbda={}, {} epochs'.format(eta, lmbda, n_eph))
# plt.axvline(x=np.argmax(val_acc), c='r', ls=':', label='best epoch: {}'.format(np.argmax(val_acc)))
# plt.axhline(y=test_data_accuracy, c='r', label='test data accuracy at best epoch: {:.3f}'.format(test_data_accuracy))
# plt.legend()
# plt.show()

# Beep(1000, 100)


# print('acc', acc)
# print('loss', loss)
# print('val_acc', val_acc)
# print('val_loss', val_loss)
# Out:
# lmbda= 0.0001
#
# eta= 0.03
#
# n_eph= 88
#
# batch_size= 10
#
# n_eph= 88
#
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 24, 24, 20)        520
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 12, 12, 20)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 40)          20040
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 4, 4, 40)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 640)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 100)               64100
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 85,670
# Trainable params: 85,670
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/88
# 75000/75000 [==============================] - 337s 4ms/step - loss: 0.0651 - accuracy: 0.9869 - val_loss: 0.0504 - val_accuracy: 0.9924
# Epoch 2/88
# 75000/75000 [==============================] - 342s 5ms/step - loss: 0.0314 - accuracy: 0.9962 - val_loss: 0.0473 - val_accuracy: 0.9923
# Epoch 3/88
# 75000/75000 [==============================] - 338s 5ms/step - loss: 0.0247 - accuracy: 0.9974 - val_loss: 0.0386 - val_accuracy: 0.9937cy:  - ETA: 1s - ETA: 0s - loss: 0.0
# Epoch 4/88
# 75000/75000 [==============================] - 339s 5ms/step - loss: 0.0214 - accuracy: 0.9979 - val_loss: 0.0398 - val_accuracy: 0.9934
# Epoch 5/88
# 75000/75000 [==============================] - 337s 4ms/step - loss: 0.0200 - accuracy: 0.9980 - val_loss: 0.0404 - val_accuracy: 0.9937
# Epoch 6/88
# 75000/75000 [==============================] - 338s 5ms/step - loss: 0.0189 - accuracy: 0.9982 - val_loss: 0.0414 - val_accuracy: 0.9925
# Epoch 7/88
# 75000/75000 [==============================] - 336s 4ms/step - loss: 0.0181 - accuracy: 0.9983 - val_loss: 0.0435 - val_accuracy: 0.9916 l - ETA: 0s - loss: 0.0181 - accuracy: 0.
# Epoch 8/88
# 75000/75000 [==============================] - 336s 4ms/step - loss: 0.0178 - accuracy: 0.9984 - val_loss: 0.0373 - val_accuracy: 0.9941
# Epoch 9/88
# 75000/75000 [==============================] - 337s 4ms/step - loss: 0.0177 - accuracy: 0.9983 - val_loss: 0.0399 - val_accuracy: 0.9934
# Epoch 10/88
# 75000/75000 [==============================] - 336s 4ms/step - loss: 0.0164 - accuracy: 0.9987 - val_loss: 0.0397 - val_accuracy: 0.9933
# Epoch 11/88
333642006, 0.033241577446460724, 0.032856013625860214, 0.03802790492773056, 0.039490167051553726, 0.03505926579236984, 0.039515454322099686, 0.03397674486041069, 0.03205796331167221, 0.039834070950746536, 0.03485479950904846, 0.03158307820558548, 0.04007180035114288, 0.03401826322078705, 0.033066485077142715, 0.04596027359366417, 0.03690899536013603, 0.039304111152887344, 0.042240627110004425, 0.03154639154672623, 0.031757667660713196, 0.03963316231966019, 0.03452390059828758, 0.03462404012680054, 0.034424711018800735, 0.03428712114691734, 0.03552522882819176, 0.03596801683306694, 0.03550573065876961, 0.032974302768707275, 0.039537593722343445, 0.03470975160598755, 0.04370081424713135, 0.036885060369968414, 0.03521310165524483, 0.03288387879729271, 0.036884818226099014, 0.035204436630010605, 0.06466062366962433, 0.03275096416473389, 0.03545575961470604, 0.03761366382241249, 0.035906776785850525, 0.037278853356838226, 0.03523357957601547, 0.0376063734292984, 0.03440992161631584, 0.03457002714276314, 0.03801031410694122, 0.0405283160507679]

# %% [markdown]
# <h1>Super-Expanding training data results in 99.5% test accuracy.<h1/>

# %% [markdown]
# <h1>rotate and eta decay (todo)<h1/>

# %%
def train_cnn_sgd(lmbda, batch_size, n_eph, eta, decay_steps, decay_rate, train_x, train_y, val_x, val_y, test_x, test_y):
    ################################################################
    #   relu CNN network as described in chapter 6
    ################################################################
    tf.random.set_seed(42)
    ################################################################
    print('lmbda= {}\n'.format(lmbda))
    print('eta= {}\n'.format(eta))
    print('n_eph= {}\n'.format(n_eph))
    print('batch_size= {}\n'.format(batch_size))
    print('n_eph= {}\n'.format(n_eph))
    print('decay_steps= {}\n'.format(decay_steps))
    print('decay_rate= {}\n'.format(decay_rate))
    ################################################################
    ################################################################
    # construct netwoek model
    input_shape = (28, 28, 1)
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Conv2D( # no padding
            20,
            (5,5),
            activation=tf.nn.relu,
            kernel_regularizer=tf.keras.regularizers.L2(l2=lmbda),
            input_shape=input_shape))

    model.add(tf.keras.layers.MaxPool2D(strides=(2,2)))

    model.add(tf.keras.layers.Conv2D( # no padding
            40,
            (5,5),
            activation=tf.nn.relu,
            kernel_regularizer=tf.keras.regularizers.L2(l2=lmbda)))

    model.add(tf.keras.layers.MaxPool2D(strides=(2,2)))

    model.add(tf.keras.layers.Flatten())

    model.add(tf.keras.layers.Dense(
            100,
            activation=tf.nn.relu,
            kernel_regularizer=tf.keras.regularizers.L2(l2=lmbda)))

    model.add(tf.keras.layers.Dense(10,activation=tf.nn.softmax))
    ################################################################
    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate=eta,
        decay_steps=decay_steps,
        decay_rate=decay_rate
    )
    ################################################################
    # compile model
    model.compile(
        optimizer=tf.keras.optimizers.SGD(
            learning_rate=lr_schedule,
            momentum=0.0,
            nesterov=False,
            name="SGD"),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    ################################################################
    model.summary()
    ################################################################
    # save the model when val_acc is best
    checkpoint_filepath = r'C:\Users\mchen\OneDrive\桌面\ml\code\tutorial\chapter6\save_model\expansion\expansion'

    model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        filepath=checkpoint_filepath,
        save_weights_only=True,
        monitor='val_accuracy',
        mode='max',
        save_best_only=True)
    ################################################################
    ################################################################
    #    train model  
    ts = time.time()
    history = model.fit(
        train_x, train_y, 
        epochs=n_eph,
        batch_size=batch_size,
        validation_data=(val_x, val_y),
        callbacks=[model_checkpoint_callback],
        shuffle=False
    )
    te = time.time()

    print('total time:', te - ts)
    acc = history.history['accuracy']
    loss = history.history['loss']
    val_acc = history.history['val_accuracy']
    val_loss = history.history['val_loss']
    ################################################################
    ################################################################
    #    load the weights for the best epoch (best val accuracy)
    model.load_weights(checkpoint_filepath)
    ################################################################
    ################################################################
    #    evaluate test data at the best epoch
    [test_data_loss, test_data_accuracy] = model.evaluate(
        test_x, test_y,
        batch_size=len(test_x)
    )
    ################################################################
    plt.plot(acc, label='train acc., best: {:.3f}'.format(max(acc)))
    plt.plot(val_acc, label='validation acc. best: {:.3f}'.format(max(val_acc)))
    plt.title('CNN relu, expanded train data, SGD, , eta={}, lmbda={}, {} epochs'.format(eta, lmbda, n_eph))
    plt.axvline(x=np.argmax(val_acc), c='r', ls=':', label='best epoch: {}'.format(np.argmax(val_acc)))
    plt.axhline(y=test_data_accuracy, c='r', label='test data accuracy at best epoch: {:.3f}'.format(test_data_accuracy))
    plt.legend()
    plt.show()
    Beep(1000, 100)
    print('acc', acc)
    print('loss', loss)
    print('val_acc', val_acc)
    print('val_loss', val_loss)

# %% [markdown]
# <h1>fine-tune h-params<h1/>

# %%
lmbda = 0.1 / 10 / 10 / 10
batch_size = 7500
n_eph = 5
eta = 0.1
decay_steps = 100
decay_rate = 0.927
    
a = train_cnn_sgd(lmbda, batch_size, n_eph, eta, decay_steps, decay_rate, train_x, train_y, val_x, val_y, test_x, test_y)
# Out:
# lmbda= 0.0001
#
# eta= 0.1
#
# n_eph= 5
#
# batch_size= 7500
#
# n_eph= 5
#
# decay_steps= 100
#
# decay_rate= 0.927
#
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_24 (Conv2D)           (None, 24, 24, 20)        520
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 12, 12, 20)        0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 8, 8, 40)          20040
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 4, 4, 40)          0
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 640)               0
# _________________________________________________________________
# dense_24 (Dense)             (None, 100)               64100
# _________________________________________________________________
# dense_25 (Dense)             (None, 10)                1010
# =================================================================
# Total params: 85,670
# Trainable params: 85,670
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 100/100 [==============================] - 77s 753ms/step - loss: 1.1407 - accuracy: 0.6773 - val_loss: 0.2684 - val_accuracy: 0.9293
# Epoch 2/5
# 100/100 [==============================] - 73s 735ms/step - loss: 0.2809 - accuracy: 0.9217 - val_loss: 0.1908 - val_accuracy: 0.9483
# Epoch 3/5
# 100/100 [==============================] - 76s 763ms/step - loss: 0.1843 - accuracy: 0.9517 - val_loss: 0.1253 - val_accuracy: 0.9690
# Epoch 4/5
# 100/100 [==============================] - 75s 749ms/step - loss: 0.1483 - accuracy: 0.9622 - val_loss: 0.1077 - val_accuracy: 0.9746
# Epoch 5/5
# 100/100 [==============================] - 74s 738ms/step - loss: 0.1268 - accuracy: 0.9685 - val_loss: 0.0988 - val_accuracy: 0.9775
# total time: 389.8224573135376
# 1/1 [==============================] - 1s 575ms/step - loss: 0.0869 - accuracy: 0.9794
# acc [0.6772733330726624, 0.921729326248169, 0.9516626596450806, 0.9621800184249878, 0.9685426950454712]
# loss [1.14072847366333, 0.2808871269226074, 0.18433035910129547, 0.1483311802148819, 0.12675741314888]
# val_acc [0.9293000102043152, 0.9483000040054321, 0.968999981880188, 0.9746000170707703, 0.9775000214576721]
# val_loss [0.2684410810470581, 0.19083967804908752, 0.1253420114517212, 0.1077381819486618, 0.09882496297359467]
